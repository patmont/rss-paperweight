# %%
import feedparser
from IPython.display import display, Image
from io import BytesIO
import PIL
from time import sleep
# %matplotlib inline

# %%
def display_img_array(ima):
    im = PIL.Image.fromarray(ima)
    bio = BytesIO()
    im.save(bio, format='png')
    display(Image(bio.getvalue(), format='png'))

# %%
d = feedparser.parse('http://rss.cnn.com/rss/cnn_topstories.rss')

# %%
for post in d.entries:
    x = Image(post.media_content[5]['url'])
    print(post.title)
    display(x)
# Out:
# Meryl Streep takes on Trump in emotional Golden Globes speech
# Golden Globe Awards: The winners list
# See the stars shine on the red carpet
# Meryl Streep gets political
# Trump drops longtime inauguration announcer
# NFL coach arrested in bar altercation
# How did Fort Lauderdale airport shooting suspect get his gun back?
# See the moment the Florida airport shooter opened fire captured
# Ft. Lauderdale airport security footage
# Trump security pick plagiarized in 2012 book
# Martin Shkreli kicked off Twitter
# Politics, 'La La Land' take center stage at Golden Globes
# Celebs attend Obama's farewell bash
# President Obama to offer 'admonitions' in farewell address
# Video shows moment of attack
# 3 duck hunters found dead in Texas bay
# Top Trump aide deflects Russia hacking question
# Biden shuts down fellow lawmakers
# Obama: 'Vladimir Putin is not on our team'
# Terrorist rams truck into soldiers in Jerusalem, killing 4
# Trump: 'Stupid' people think warm ties with Russia is bad
# Fiat Chrysler to put $1 billion into U.S. jobs
# Ethics office: Trump nominees still not properly vetted
# US consulate official shot in Mexico; suspect arrested
# See inside Ft. Lauderdale airport and hear from eyewitnesses
# Grandparents among victims of Ft. Lauderdale shooting
# Shooting suspect developed mental issues after Iraq, brother says
# 'The backpack saved my life': Airport survivor's close call
# Shooting raises questions about flying with firearms
# Opinion: Airport security needs a 9/11 style upgrade
# Opinion: American hostages more likely to die than others
# SpaceX delays launch due to weather
# See Earth from Mars
# How NASA's black mathematicians multiplied success
# Neil deGrasse Tyson calls for audacious science
# Malia and Sasha Obama: See how they've grown!
# Opinion: How Obama should say goodbye
# Opinion: 'Clinton for mayor' -- crazy talk?
# Secret Service chief: 'No friction' with Trump's private security
# Boris Johnson arrives in US for talks with Trump team
# 10 most damning findings from report on Russian hacking
# Former Iranian President Rafsanjani dies at 82
# Athlete says she was forced to wet herself on train
# Winter storm moves up East Coast
# This city has smog police
# London breaches annual air pollution limits 5 days into 2017
# Northern California could see worst flooding in 10 years
# Four charged for Facebook Live beating video
# Inauguration artists: Who's in, who's out
# Mysterious radio signal traced to dwarf galaxy
# First Amendment advocate dies
# Sisters kicked off plane, miss dad's final moments
# Lake Erie plane crash: Possible remains found
# Teacher fulfills promise after 18 years
# Michelle Obama: 'I hope I've made you proud'
# Russian official: Republicans trust Putin more than Democrats
# Mexico's Fox trolls Trump: 'Are you a legitimate president?'
# Ivory Coast president says agreement reached with soldiers over bonuses
# 3rd Brazilian prison riot in a week leaves 4 dead
# Mom's video hiding from toddlers goes viral
# Controversial abortion bills pass Kentucky legislature
# First days of 2017 bring new 'bathroom bills'
# US cancer deaths down 25% since 1991
# Jeff Sessions faces 'Washington's bloodsport'
# Mattis, Trump team already at odds
# This funeral had a pole dancing procession
# Beer may soon be pouring from your Keurig
# Mascot falls, video goes viral
# College Football Playoff Championships: What to know
# Killer whale at center of 'Blackfish' dies
